# %% [markdown]
# <a href="https://colab.research.google.com/github/Itto-ryu/CPEN21A-Basic-Prog.-Test/blob/main/CPEN21A_Basic_Prog_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Basic Python Programming

# %%
if 6>3:
  print("six is greater than three")
# Out:
# six is greater than three

# %%
print("Test yo") #TEstTestTest
# Out:
# Test yo

# %%
x=5
y=10
print (x)
print(y)
# Out:
# 5
# 10

# %%
b="sally"
b=int(4)
print(b)
# Out:
# 4

# %%
b="sally"
b=float(4)
print(b)
# Out:
# 4.0

# %%
x=100
y="Ryu"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x,y,z=7,8,9
print(x)
print(y)
print(z)
# Out:
# 7
# 8
# 9

# %%
x=y=z=20
print(x)
print(y)
print(z)
# Out:
# 20
# 20
# 20

# %%
x="enjoying"
print("programming is "+x)
# Out:
# programming is enjoying

# %%
r="succeeded"
print("you have "+r)
# Out:
# you have succeeded

# %%
r="you have "
R="succeeded"
u=r+R
print(u)
# Out:
# you have succeeded

# %%
x=25
y=65
print(x+y)
print(x-y)
# Out:
# 90
# -40

# %%
x+=5
print(x)
# Out:
# 30

# %%
y+=10
print(y)
# Out:
# 75

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
x<100 and y>100
# Out:
# False

# %%
x<100 or y>100
# Out:
# True

# %%
not(x>100 and y>100)
# Out:
# True

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True
